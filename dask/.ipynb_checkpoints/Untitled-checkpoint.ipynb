# %%
from dask.distributed import Client
import dask.dataframe as dd
import s3fs
import boto3
client = Client(n_workers=10, threads_per_worker=100, memory_limit='10GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:50510' processes=10 threads=1000, memory=85.90 GB>

# %%
client.restart()
# Out:
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# <Client: 'tcp://127.0.0.1:50510' processes=0 threads=0, memory=0 B>

# %%
# NBA Data Sources
nba_team = dd.read_csv('s3://sportsdatawarehouse/NBA/teams/NBA_teams_team stats_*.csv')
nba_player = dd.read_csv('s3://sportsdatawarehouse/NBA/players/NBA_Players_per game stats_*.csv')
nba_salary = dd.read_csv('s3://sportsdatawarehouse/NBA/salary/*nbasalary.csv')
nba_teamid = dd.read_csv('s3://sportsdatawarehouse/key_identifiers/nba_team.csv')
nba_playerid = dd.read_csv('s3://sportsdatawarehouse/key_identifiers/nba_players.csv')
nba_game_details = dd.read_csv('s3://sportsdatawarehouse/NBA/games_details.csv')
# WNBA Data Sources
wnba_team = dd.read_csv('s3://sportsdatawarehouse/WNBA/team/wbna_team*.csv')
wnba_player = dd.read_csv('s3://sportsdatawarehouse/WNBA/players/wbna_player*.csv')
wnba_salary = dd.read_csv('s3://sportsdatawarehouse/WNBA/salaries/*_team_salaries.csv')
wnba_teamid = dd.read_csv('s3://sportsdatawarehouse/key_identifiers/wnba_team.csv')
wnba_playerid = dd.read_csv('s3://sportsdatawarehouse/key_identifiers/wnba_players.csv')

# Men College Basketball
ncam_events = dd.read_csv('s3://sportsdatawarehouse/NCAAmen/men_ncaa_data/men_ncaa_events.csv')
ncam_players = dd.read_csv(
    's3://sportsdatawarehouse/NCAAmen/men_ncaa_data/DataFiles/playbyplay/files/Players_*.csv')
ncam_cities = dd.read_csv('s3://sportsdatawarehouse/NCAAmen/men_ncaa_data/mncaa_cities.csv')
ncam_coaches = dd.read_csv('s3://sportsdatawarehouse/NCAAmen/men_ncaa_data/mncaa_coaches.csv')
ncam_conference = dd.read_csv('s3://sportsdatawarehouse/NCAAmen/men_ncaa_data/mncaa_conference.csv')
ncam_conference_games = dd.read_csv('s3://sportsdatawarehouse/NCAAmen/men_ncaa_data/mncaa_confgames.csv')
ncam_gamecities = dd.read_csv('s3://sportsdatawarehouse/NCAAmen/men_ncaa_data/mncaa_gamecities.csv')
ncam_seasongames = dd.read_csv('s3://sportsdatawarehouse/NCAAmen/men_ncaa_data/mncaa_season_games.csv')
ncam_teamconference = dd.read_csv('s3://sportsdatawarehouse/NCAAmen/men_ncaa_data/mncaa_tconf.csv')
ncam_teams = dd.read_csv('s3://sportsdatawarehouse/NCAAmen/men_ncaa_data/mncaa_teams.csv')
ncam_tournament = dd.read_csv('s3://sportsdatawarehouse/NCAAmen/men_ncaa_data/mncaa_tournament.csv')

# Women College Basketball
ncaw_players = dd.read_csv('s3://sportsdatawarehouse/NCAAwomen/women_ncaa_data/data/WPlayers.csv')
ncaw_cities = dd.read_csv('s3://sportsdatawarehouse/NCAAwomen/women_ncaa_data/wncaa_cities.csv')
ncaw_conference = dd.read_csv('s3://sportsdatawarehouse/NCAAwomen/women_ncaa_data/wncaa_conference.csv')
ncaw_gamecities = dd.read_csv('s3://sportsdatawarehouse/NCAAwomen/women_ncaa_data/wncaa_gamecities.csv')
ncaw_seasongames = dd.read_csv('s3://sportsdatawarehouse/NCAAwomen/women_ncaa_data/wncaa_season_games.csv')
ncaw_season = dd.read_csv('s3://sportsdatawarehouse/NCAAwomen/women_ncaa_data/wncaa_seasons.csv')
ncaw_teamconference = dd.read_csv('s3://sportsdatawarehouse/NCAAwomen/women_ncaa_data/wncaa_tconf.csv')
ncaw_teams = dd.read_csv('s3://sportsdatawarehouse/NCAAwomen/women_ncaa_data/wncaa_teams.csv')
ncaw_tournament = dd.read_csv('s3://sportsdatawarehouse/NCAAwomen/women_ncaa_data/wncaa_tournament.csv')
ncam_events = dd.read_csv('s3://sportsdatawarehouse/NCAAmen/men_ncaa_data/men_ncaa_events.csv')
# MLB Data Sources

mlb_players = dd.read_csv('s3://sportsdatawarehouse/MLB/mlb_players.csv')
mlb_teams = dd.read_csv('s3://sportsdatawarehouse/MLB/mlb_teams.csv',dtype={'DivWin': 'object',
       'WCWin': 'object',
       'divID': 'object'})
mlb_allstars = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/AllstarFull.csv')
mlb_appearances = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/Appearances.csv',
                              dtype={'G_dh': 'float64'})
mlb_awardmanagers = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/AwardsManagers.csv')
mlb_awardplayers = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/AwardsShareManagers.csv')
mlb_awardshared_players = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/AwardsShareManagers.csv')
mlb_batting = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/Batting.csv')
mlb_postbatting = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/BattingPost.csv')
mlb_college = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/CollegePlaying.csv')
mlb_fielding = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/Fielding.csv',
                           dtype={'E': 'float64', 'InnOuts': 'float64'})
mlb_fieldingof = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/FieldingOF.csv')
mlb_fieldingof = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/FieldingOF.csv')
mlb_fieldingpost = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/FieldingPost.csv')
mlb_halloffame = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/HallOfFame.csv')
mlb_homegames = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/HomeGames.csv')
mlb_managers = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/Managers.csv')
mlb_halfmanagers = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/ManagersHalf.csv')
mlb_parks = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/Parks.csv')
mlb_players = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/People.csv')
mlb_pitching = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/Pitching.csv',
                           dtype={'BFP': 'float64'})
mlb_postpitching = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/PitchingPost.csv')
mlb_salaries = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/Salaries.csv')
mlb_postseries = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/SeriesPost.csv')
mlb_teams = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/Teams.csv', dtype={'DivWin': 'object',
                                                                                   'WCWin': 'object',
                                                                                   'divID': 'object'})
mlb_teams_franch = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/TeamsFranchises.csv')
mlb_halfteams = dd.read_csv('s3://sportsdatawarehouse/MLB/2019/core/TeamsHalf.csv')

# women soccer
wsoccer_stadium = dd.read_csv('s3://sportsdatawarehouse/women_soccer/stadium_info.csv')
wsoccer_fieldplayer = dd.read_csv('s3://sportsdatawarehouse/women_soccer/wsoccer_fieldplayer.csv')
wsoccer_goal = dd.read_csv('s3://sportsdatawarehouse/women_soccer/wsoccer_goal.csv')
wsoccer_player = dd.read_csv('s3://sportsdatawarehouse/women_soccer/wsoccer_player.csv')
wsoccer_playfield = dd.read_csv('s3://sportsdatawarehouse/women_soccer/wsoccer_playfield.csv')
wsoccer_playstats = dd.read_csv('s3://sportsdatawarehouse/women_soccer/wsoccer_playstats.csv')
wsoccer_franch = dd.read_csv('s3://sportsdatawarehouse/women_soccer/wsoccerfranchises.csv')
wsoccer_games_r = dd.read_csv('s3://sportsdatawarehouse/women_soccer/wsoccergameresults.csv')
wsoccer_teams = dd.read_csv('s3://sportsdatawarehouse/women_soccer/wsoccerteam_stats.csv')

# NFL Football & Superbowl Data Sources
afc = dd.read_csv('s3://sportsdatawarehouse/NFL_f/AFC_records.CSV')
afl = dd.read_csv('s3://sportsdatawarehouse/NFL_f/AFL_records.CSV')
defense_game_stat = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Defense_GAME_STATS.CSV')
defense_intecep = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Defense_INTERCEPTIONS.CSV')
defense_pass = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Defense_PASSING.CSV')
defense_rece = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Defense_RECEIVING.CSV')
defense_rush = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Defense_RUSHING.CSV')
defense_score = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Defense_SCORING.CSV')
defense_tackle = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Defense_TACKLES.CSV')
nfc = dd.read_csv('s3://sportsdatawarehouse/NFL_f/NFC_records.CSV')
nfl_records = dd.read_csv('s3://sportsdatawarehouse/NFL_f/NFL_records.CSV')
offense_field = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Offense_FIELD_GOALS.CSV')
offense_game_stat = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Offense_GAME_STATS.CSV')
offense_kicking = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Offense_KICKING.CSV')
offense_kick_return = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Offense_KICK_RETURNS.CSV')
offense_offensive_line = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Offense_OFFENSIVE_LINE.CSV')
offence_pass = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Offense_PASSING.CSV')
offense_pun = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Offense_PUNTING.CSV')
offense_rece = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Offense_RECEIVING.CSV')
offense_rush = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Offense_RECEIVING.CSV')
offense_score = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Offense_SCORING.CSV')
offense_touch = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Offense_TOUCHDOWNS.CSV')
merged = dd.read_csv('s3://sportsdatawarehouse/NFL_f/clean_offense_def.csv',
                     dtype={'Defense_passing_1stpct': 'float64',
                            'Defense_rushing_1stpct': 'float64',
                            'Offense_kicking_Avg': 'float64',
                            'Offense_kicking_Pct': 'float64',
                            'Offense_kicking_returns_Avg': 'float64',
                            'Offense_passing_1stpct': 'float64',
                            'Offense_punting_Net_Avg': 'float64',
                            'Offense_rushing_1stpct': 'float64'})
superbowl = dd.read_csv('s3://sportsdatawarehouse/NFL_f/Superbowl_winners.CSV')

# %%
def remove_pct(df):
    df.columns = df.columns.str.replace('%', 'pct')
    df = df.fillna(0.0)
    # df = df.drop('Unnamed: 0', axis=1)
    return df


def merge_columns(df1, df2, *cols):
    for col in cols:
        data = dd.merge(df1, df2, on=col)
        # data = data.drop('Unnamed: 0', axis=1)
    return data


def drop_values(df):
    data = df.dropna()
    return data.compute()

# %%
nba_teams = remove_pct(nba_team)
nba_players = remove_pct(nba_player)
nba_game_d = drop_values(nba_game_details)
wnba_teams = remove_pct(wnba_team)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-a9061e2058af> in <module>
# ----> 1 nba_teams = remove_pct(nba_team)
#       2 nba_players = remove_pct(nba_player)
#       3 nba_game_d = drop_values(nba_game_details)
#       4 wnba_teams = remove_pct(wnba_team)
#
# <ipython-input-4-a2e48bf484b8> in remove_pct(df)
#       3     df = df.fillna(0.0)
#       4     # df = df.drop('Unnamed: 0', axis=1)
# ----> 5     return df.compute()
#       6
#       7
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# ...

# %%
nba_teams = remove_pct(nba_team)
nba_players = remove_pct(nba_player)
nba_game_d = drop_values(nba_game_details)
wnba_teams = remove_pct(wnba_team)
cols = {'Western Conference': 'Team'}
wnba_teams = wnba_teams.rename(columns=cols)
wnba_players = remove_pct(wnba_player)

nba_teams_merged = merge_columns(nba_teamid, nba_teams, 'Team')
nba_players_merged = merge_columns(nba_playerid, nba_players, 'Player')
wnba_teams_merged = merge_columns(wnba_teamid, wnba_teams, 'Team')
wnba_players_merged = merge_columns(wnba_playerid, wnba_players, 'Player')
nba_salaries = nba_salary
wnba_salaries = wnba_salary

# %%
# Melt Dataframes
nba_team_reshaped = nba_teams_merged.melt(id_vars=['Team', 'season'],
                                          var_name='statistic_name', value_name='statistic')
nba_players_reshaped = nba_players_merged.melt(id_vars=['Player', 'Pos', 'Age', 'Tm', 'season'],
                                               var_name='statistic_name', value_name='statistic')
wnba_team_reshaped = wnba_teams_merged.melt(id_vars=['Team', 'season'],
                                            var_name='statistic_name', value_name='statistic')
wnba_player_reshaped = wnba_players_merged.melt(id_vars=['Player', 'Tm', 'Pos', 'season'],
                                                var_name='statistic_name', value_name='statistic')

# College Ball
men_players = drop_values(ncam_players)
men_cities = drop_values(ncam_cities)
men_coaches = drop_values(ncam_coaches)
men_conference = drop_values(ncam_conference)
men_conference_games = drop_values(ncam_conference_games)
men_seasongames = drop_values(ncam_seasongames)
men_teamconference = drop_values(ncam_teamconference)
men_teams = drop_values(ncam_teams)
men_tournament = drop_values(ncam_tournament)
women_players = drop_values(ncaw_players)
women_cities = drop_values(ncaw_cities)
women_conference = drop_values(ncaw_conference)
women_gamecities = drop_values(ncaw_gamecities)
women_seasongames = drop_values(ncaw_seasongames)
women_season = drop_values(ncaw_season)
women_teamconference = drop_values(ncaw_teamconference)
women_teams = drop_values(ncaw_teams)
women_tournament = drop_values(ncaw_tournament)

# %%
# MLB Baseball
fill_star = {'startingPos': 0.0}
mlb_allstar = mlb_allstars.fillna(fill_star)
mlb_allstar = mlb_allstar.dropna(subset=['yearID', 'gameNum', 'gameID'])
fill2 = {'lgID': 'n', 'GS': 0.0, 'G_defense': 0.0, 'G_dh': 0.0, 'G_ph': 0.0, 'G_pr': 0.0}
mlb_appearance = mlb_appearances.fillna(fill2)
mlb_awardmanager = mlb_awardmanagers.fillna({'tie': 'none', 'notes': 'none'})
mlb_awardplayer = mlb_awardplayers.fillna({'pointsMax': 0.0})
mlb_awardshared_player = mlb_awardshared_players.fillna({'votesFirst': 0.0})
mlb_bat = mlb_batting.fillna({'lgID': 'n', 'RBI': 0.0, 'SB': 0.0, 'CS': 0.0, 'SO': 0.0,
                              'IBB': 0.0, 'HBP': 0.0, 'SH': 0.0, 'SF': 0.0, 'GIDP': 0.0})
mlb_postbat = mlb_postbatting.fillna({'CS': 0.0, 'HBP': 0.0, 'SH': 0.0, 'SF': 0.0, 'GIDP': 0.0})
mlb_field = mlb_fielding.fillna({'lgID': 'n', 'GS': 0.0, 'InnOuts': 0.0, 'PB': 0.0, 'WP': 0.0, 'SB': 0.0,
                                 'CS': 0.0, 'ZR': 0.0})
mlb_fieldof = mlb_fieldingof.fillna({'Glf': 0.0, 'Gcf': 0.0, 'Grf': 0.0})
mlb_fieldpost = mlb_fieldingpost.fillna({'PB': 0.0, 'SB': 0.0, 'CS': 0.0})

mlb_fame = mlb_halloffame.fillna({'ballots': 0.0, 'needed': 0.0, 'votes': 0.0, 'needed_note': 'none'})

mlb_homegame = mlb_homegames.fillna({'league.key': 'n'})

mlb_manager = mlb_managers.fillna({'lgID': 'n', 'plyrMgr': 'N'})
mlb_park = mlb_parks.fillna({'park.alias': 'none', 'country': 'n'})
mlb_player = mlb_players.fillna({'birthYear': 0.0, 'birthMonth': 0.0, 'birthDay': 0.0, 'birthCountry': 'none',
                                 'birthState': 'none', 'birthCity': 'none', 'deathYear': 0.0, 'deathMonth': 0.0,
                                 'deathCountry': 'none', 'deathState': 'none', 'deathCity': 'none',
                                 'nameFirst': 'unknown', 'nameGiven': 'unknown', 'weight': 0.0, 'height': 0.0,
                                 'bats': 'n', 'throws': 'n'})
mlb_player = mlb_player.dropna(subset=['debut', 'finalGame', 'retroID', 'bbrefID'])
mlb_pitch = mlb_pitching.fillna({'lgID': 'n', 'BAOpp': 0.0, 'ERA': 0.0, 'IBB': 0.0, 'HBP': 0.0, 'SH': 0.0,
                                 'SF': 0.0, 'GIDP': 0.0})
mlb_postpitch = mlb_postpitching.fillna(
    {'WP': 0.0, 'BK': 0.0, 'BFP': 0.0, 'BAOpp': 0.0, 'ERA': 0.0, 'IBB': 0.0, 'HBP': 0.0, 'SH': 0.0,
     'SF': 0.0, 'GIDP': 0.0})
mlb_team = mlb_teams.fillna(
    {'lgID': 'n', 'divID': 'n', 'Ghome': 0.0, 'DivWin': 'n', 'WCWin': 'n', 'LgWin': 'n', 'WSWin': 'n',
     'BB': 0.0, 'SO': 0.0, 'SB': 0.0, 'CS': 0.0, 'HBP': 0.0, 'SF': 0.0, 'park': 'n', 'attendance': 0.0})

# Women Soccer
wsoc_stadium = wsoccer_stadium
wsoc_fieldplayer = wsoccer_fieldplayer
wsoc_goal = wsoccer_goal
wsoc_player = wsoccer_player
wsoc_playfield = wsoccer_playfield
wsoc_playstat = wsoccer_playstats
wsoc_franch = wsoccer_franch
wsoc_games_r = wsoccer_games_r
wsoc_teams = wsoccer_teams

# NFL
afc_rec = drop_values(afc)
afl_rec = drop_values(afl)
d_game_stat = drop_values(defense_game_stat)
d_intecep = drop_values(defense_intecep)
d_pass = drop_values(defense_pass)
d_receive = drop_values(defense_rece)
defense_r = drop_values(defense_rush)
defense_s = drop_values(defense_score)
d_tackle = drop_values(defense_tackle)
nfc_rec = drop_values(nfc)
nfl_rec = drop_values(nfl_records)
o_field = drop_values(offense_field)
o_game = drop_values(offense_game_stat)
o_k = drop_values(offense_kicking)
off_kickreturn = drop_values(offense_kick_return)
off_line = drop_values(offense_offensive_line)
of_pass = drop_values(offence_pass)
of_pun = drop_values(offense_pun)
of_rece = drop_values(offense_rece)
off_rush = drop_values(offense_rush)
off_score = drop_values(offense_score)
off_touch = drop_values(offense_touch)
merg_data = drop_values(merged)
superb = drop_values(superbowl)

# %%
client.close()
